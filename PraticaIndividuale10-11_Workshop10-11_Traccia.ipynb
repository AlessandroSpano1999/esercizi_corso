# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Set the style and color palette of the plots
sns.set(style="whitegrid")
sns.set_palette("pastel")

# %%
# Leggere il file xlsx
startup=pd.read_excel('startup-expansion.xlsx')
startup=startup.rename(columns=str.lower)
startup.columns = [x.replace(" ", "_") for x in startup.columns]

# %%
# Visualizzare le prime 10 righe
startup.head(10)
# Out:
#    store_id           city          state sales_region new_expansion  \
# 0         1         Peoria        Arizona     Region 2           Old
# 1         2        Midland          Texas     Region 2           Old
# 2         3        Spokane     Washington     Region 2           Old
# 3         4         Denton          Texas     Region 2           Old
# 4         5  Overland Park         Kansas     Region 2           Old
# 5         6        Yonkers       New York     Region 1           Old
# 6         7     Birmingham        Alabama     Region 1           Old
# 7         8        Antioch     California     Region 2           Old
# 8         9      Worcester  Massachusetts     Region 1           Old
# 9        10      Rochester       New York     Region 1           Old
#
#    marketing_spend  revenue
# 0             2601    48610
# 1             2727    45689
# 2             2768    49554
# 3             2759    38284
# 4             2869    59887
# 5             3080    53827
# ...

# %%
# Visualizzare le ultime 10 righe
startup.tail(10)
# Out:
#      store_id              city       state sales_region new_expansion  \
# 140       141       Chattanooga   Tennessee     Region 2           New
# 141       142             Tempe     Arizona     Region 2           New
# 142       143            Joliet    Illinois     Region 1           New
# 143       144  Rancho Cucamonga  California     Region 2           New
# 144       145          Glendale  California     Region 2           New
# 145       146          Paterson  New Jersey     Region 1           New
# 146       147       Brownsville       Texas     Region 2           New
# 147       148          Rockford    Illinois     Region 1           New
# 148       149   College Station       Texas     Region 2           New
# 149       150     Thousand Oaks  California     Region 2           New
#
#      marketing_spend  revenue
# 140             3587    55357
# 141             2911    48954
# 142             3279    48315
# 143             2945    52366
# 144             2363    49376
# ...

# %%
# Visualizzare le informazioni sul DataFrame
startup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   store_id         150 non-null    int64
#  1   city             150 non-null    object
#  2   state            150 non-null    object
#  3   sales_region     150 non-null    object
#  4   new_expansion    150 non-null    object
#  5   marketing_spend  150 non-null    int64
#  6   revenue          150 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.3+ KB

# %%
# Visualizzare le statistiche descrittive
startup[['marketing_spend','revenue']].describe().round(2)
# Out:
#        marketing_spend   revenue
# count           150.00    150.00
# mean           2893.15  39301.43
# std             367.86  15465.75
# min            1811.00  15562.00
# 25%            2662.25  21113.50
# 50%            2898.00  42993.00
# 75%            3111.50  51145.50
# max            3984.00  68828.00

# %%
# I valori unici di City
startup.city.unique()
# Out:
# array(['Peoria', 'Midland', 'Spokane', 'Denton', 'Overland Park',
#        'Yonkers', 'Birmingham', 'Antioch', 'Worcester', 'Rochester',
#        'Rialto', 'Santa Maria', 'Las Cruces', 'Jackson', 'Hillsboro',
#        'Temecula', 'Tallahassee', 'Fontana', 'Kent', 'Broken Arrow',
#        'Concord', 'Modesto', 'Montgomery', 'Burbank', 'Elk Grove',
#        'Port St. Lucie', 'Elizabeth', 'Salt Lake City', 'Waco', 'Edison',
#        'Boulder', 'Grand Rapids', 'Tyler', 'Charleston', 'Huntsville',
#        'Pearland', 'Inglewood', 'Oxnard', 'Miramar', 'Cape Coral',
#        'Syracuse', 'Newport News', 'Lewisville', 'Carrollton',
#        'San Bernardino', 'Pasadena', 'Roseville', 'Murrieta',
#        'San Angelo', 'Olathe', 'Akron', 'Fullerton', 'Manchester',
#        'Everett', 'West Covina', 'Thornton', 'Hampton', 'Waterbury',
#        'Ventura', 'Davenport', 'Columbia', 'Simi Valley', 'Richmond',
#        'Little Rock', 'El Cajon', 'Santa Clara', 'Oceanside', 'Davie',
# ...

# %%
# Conteggio delle città unici
len(startup.city.unique())
# Out:
# 149

# %%
# Conteggio delle citta
# Ragionare sull'output di questa domanda:
#ci sono due citta Rochester in due stati diversi
startup.city.value_counts()
# Out:
# Rochester        2
# Killeen          1
# Wichita Falls    1
# Naperville       1
# Clovis           1
#                 ..
# Akron            1
# Fullerton        1
# Manchester       1
# Everett          1
# Thousand Oaks    1
# Name: city, Length: 149, dtype: int64

# %%
# Conteggio degli stati
startup.state.value_counts()
# Out:
# California        40
# Texas             17
# Florida           12
# Washington         7
# Colorado           5
# Illinois           5
# Georgia            4
# Alabama            4
# Connecticut        4
# New Jersey         4
# Arizona            3
# Tennessee          3
# Iowa               3
# Michigan           3
# South Carolina     3
# Utah               3
# Massachusetts      3
# Kansas             3
# New York           3
# Louisiana          2
# North Carolina     2
# Ohio               2
# Virginia           2
# Oregon             2
# Mississippi        1
# New Mexico         1
# Arkansas           1
# New Hampshire      1
# Oklahoma           1
# Montana            1
# Indiana            1
# South Dakota       1
# Minnesota          1
# Wisconsin          1
# Rhode Island       1
# Name: state, dtype: int64

# %%
# Conteggio degli stati unici
startup.state.unique()
# Out:
# array(['Arizona', 'Texas', 'Washington', 'Kansas', 'New York', 'Alabama',
#        'California', 'Massachusetts', 'New Mexico', 'Mississippi',
#        'Oregon', 'Florida', 'Oklahoma', 'New Jersey', 'Utah', 'Colorado',
#        'Michigan', 'South Carolina', 'Virginia', 'Ohio', 'New Hampshire',
#        'Connecticut', 'Iowa', 'Arkansas', 'Tennessee', 'North Carolina',
#        'Georgia', 'Illinois', 'Montana', 'Indiana', 'South Dakota',
#        'Louisiana', 'Minnesota', 'Wisconsin', 'Rhode Island'],
#       dtype=object)

# %%
# Conteggio degli stati unici
startup.state.nunique()
# Out:
# 35

# %%
# Regione uniche
startup.sales_region.unique()
# Out:
# array(['Region 2', 'Region 1'], dtype=object)

# %%
# Conteggio delle regioni
startup.sales_region.value_counts()
# Out:
# Region 2    86
# Region 1    64
# Name: sales_region, dtype: int64

# %%
# New Expansion uniche
startup.new_expansion.unique()
# Out:
# array(['Old', 'New'], dtype=object)

# %%
# Conteggio dei valori per New Expansion
startup.new_expansion.value_counts()
# Out:
# Old    140
# New     10
# Name: new_expansion, dtype: int64

# %%
# Verifica se ci sono duplicati nel mio dataframe
count=0
for x in range (len(startup)):
    if startup.duplicated()[x]==True:
        print(startup.iloc[x])
    else:
        continue       
startup[startup.city=='Rochester']
# Out:
#      store_id       city      state sales_region new_expansion  \
# 9          10  Rochester   New York     Region 1           Old
# 124       125  Rochester  Minnesota     Region 1           Old
#
#      marketing_spend  revenue
# 9               2984    64906
# 124             2854    18099

# %%
# Crea un grafico a barre per visualizzare il numero di startup per regione
    
plt.figure(figsize=(5, 3))
plt.title('Salaes Region')
plt.ylabel('Count')
plt.hist(startup.sales_region,bins=3)
plt.grid(True)
plt.show()

# %%
startup.sales_region.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.countplot(x=startup.sales_region)
plt.grid(True)
plt.show()

# %%
# Crea un grafico a barre per visualizzare il numero di startup per stato
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(6, 4))
plt.bar(startup.state.value_counts().index, startup.state.value_counts())
plt.xticks (rotation=90)
plt.xlabel('Stati')
plt.ylabel('Valori')
plt.title('Startup per Stato')

# Mostra l'istogramma
plt.show()

# %%
#un ROAS 400 o superiore indica una campagna di successo.
indice=startup.groupby(by='state')['ROAS'].mean()
plt.figure(figsize=(10, 8))
plt.bar(indice.index, indice,color='g')
plt.xticks (indice.index,rotation=90)
legenda=plt.legend(['ROAS'],prop={'size': 8})
plt.xlabel('Stati')
plt.ylabel('Valori')
plt.title('Guadagni,spese e ROAS')
# Out:
# Text(0.5, 1.0, 'Guadagni,spese e ROAS')

# %%
startup[(startup['ROAS']<1000)].
# Out:
#      store_id              city           state sales_region new_expansion  \
# 7           8           Antioch      California     Region 2           Old
# 10         11            Rialto      California     Region 2           Old
# 11         12       Santa Maria      California     Region 2           Old
# 12         13        Las Cruces      New Mexico     Region 2           Old
# 14         15         Hillsboro          Oregon     Region 2           Old
# 15         16          Temecula      California     Region 2           Old
# 19         20      Broken Arrow        Oklahoma     Region 2           Old
# 23         24           Burbank      California     Region 2           Old
# 29         30            Edison      New Jersey     Region 1           Old
# 30         31           Boulder        Colorado     Region 2           Old
# 32         33             Tyler           Texas     Region 2           Old
# ...

# %%
# Visualizzare la distribuzione del Revenue con pandas
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize=(4.2, 3.5))
startup.revenue.hist()
plt.ylabel('Frequency')
plt.xlabel('Revenue')
# Out:
# Text(0.5, 0, 'Revenue')

# %%
# Visualizzare la distribuzione del Marketing Spend con pandas
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize=(4.5, 3.5))
startup.marketing_spend.hist()
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Visualizzare la distribuzione del Marketing Spend con Seaborn
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Marketing Spend', ylabel='Density'>

# %%
startup['marketing_spend'].sum()
# Out:
# 433972

# %%
plt.figure(figsize = (4.5,3.5))
sns.distplot(startup['marketing_spend'],kde=True)
plt.ylabel('Density')
plt.xlabel('Marketing Spend')
# Out:
# C:\Users\aless\AppData\Local\Temp\ipykernel_23948\2502282697.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(startup['marketing_spend'],kde=True)
# Text(0.5, 0, 'Marketing Spend')

# %%
# Visualizzare la relazione tra Marketing Spend e Revenue

# %%
plt.figure(figsize=(8,5))
plt.scatter(x='marketing_spend',y='revenue',s=10,data=startup[startup['new_expansion']=='Old'],color='lightblue')
plt.scatter(x='marketing_spend',y='revenue',s=10,data=startup[startup['new_expansion']=='New'],color='orange',marker='x')
plt.ylabel('Revenue')
plt.xlabel('Marketing Spend')
plt.title('Relazione tra Marketing Spend e Revenue')
legenda=plt.legend(['Old', 'New'],prop={'size': 8},loc=2)
legenda.set_title('New Expansion')
plt.show()

# %%
startup[(startup['marketing_spend']>=0)&(startup['revenue']<=30000)]
# Out:
#      store_id              city           state sales_region new_expansion  \
# 7           8           Antioch      California     Region 2           Old
# 10         11            Rialto      California     Region 2           Old
# 11         12       Santa Maria      California     Region 2           Old
# 12         13        Las Cruces      New Mexico     Region 2           Old
# 14         15         Hillsboro          Oregon     Region 2           Old
# 15         16          Temecula      California     Region 2           Old
# 19         20      Broken Arrow        Oklahoma     Region 2           Old
# 23         24           Burbank      California     Region 2           Old
# 29         30            Edison      New Jersey     Region 1           Old
# 30         31           Boulder        Colorado     Region 2           Old
# 32         33             Tyler           Texas     Region 2           Old
# ...

# %%
startup[startup['state']=='California'].sort_values('ROAS',ascending=False)
# Out:
#      store_id              city       state sales_region new_expansion  \
# 37         38            Oxnard  California     Region 2           Old
# 102       103           Visalia  California     Region 2           Old
# 118       119  Huntington Beach  California     Region 2           Old
# 144       145          Glendale  California     Region 2           New
# 17         18           Fontana  California     Region 2           Old
# 134       135        Santa Rosa  California     Region 2           Old
# 21         22           Modesto  California     Region 2           Old
# 79         80        Costa Mesa  California     Region 2           Old
# 66         67         Oceanside  California     Region 2           Old
# 143       144  Rancho Cucamonga  California     Region 2           New
# 44         45    San Bernardino  California     Region 2           Old
# 80         81      Garden Grove  California     Region 2           Old
# ...

# %%
#le new che vanno molto bene si trovano in prossimità delle big city o citta con molte strade e trafficate o zone ricche
#la new con 25% si trova in un punto poco strategico e poco trafficato
#dipende anche dalla densita di popolazione per km^2
startup[startup['new_expansion']=='New']
# Out:
#      store_id              city       state sales_region new_expansion  \
# 140       141       Chattanooga   Tennessee     Region 2           New
# 141       142             Tempe     Arizona     Region 2           New
# 142       143            Joliet    Illinois     Region 1           New
# 143       144  Rancho Cucamonga  California     Region 2           New
# 144       145          Glendale  California     Region 2           New
# 145       146          Paterson  New Jersey     Region 1           New
# 146       147       Brownsville       Texas     Region 2           New
# 147       148          Rockford    Illinois     Region 1           New
# 148       149   College Station       Texas     Region 2           New
# 149       150     Thousand Oaks  California     Region 2           New
#
#      marketing_spend  revenue    ROAS  ROAS%  profit
# 140             3587    55357  1543.0   43.0   51770
# 141             2911    48954  1682.0   58.0   46043
# ...

# %%
plt.figure(figsize=(8,5))
plt.scatter(x='marketing_spend',y='revenue',s=10,data=startup[startup['sales_region']=='Region 1'],color='lightblue')
plt.scatter(x='marketing_spend',y='revenue',s=10,data=startup[startup['sales_region']=='Region 2'],color='red',marker='x')
plt.ylabel('Revenue')
plt.xlabel('Marketing Spend')
plt.title('Relazione tra Marketing Spend e Revenue')
legenda=plt.legend(['Region 1', 'Region 2'],prop={'size': 8},loc=2)
legenda.set_title('New Expansion')
plt.show()

# %%
# Qual è il totale delle entrate ('Revenue') ottenuto per ciascuno degli Stati nel DataFrame df, 
# considerando solo le righe in cui 'New Expansion' è uguale a 'Old', 
# e quali sono i primi 10 Stati in ordine decrescente di questo totale di entrate?

# %%
#soluzione con pandas
startup_old=startup[startup['new_expansion']=='Old'].groupby(['state']).revenue.sum() #ordino in basi agli stati e ai negozi vecchi
startup_old.sort_values(ascending=False).iloc[0:10] #selezioni le prime 10 righe in ordine decrescente
# Out:
# state
# California     1362468
# Texas           554964
# Florida         479023
# Washington      298013
# Alabama         221025
# New York        160046
# Connecticut     158511
# Georgia         157656
# Colorado        156495
# Michigan        147759
# Name: revenue, dtype: int64

# %%
#soluzione SQl Server
conn=pyodbc.connect('Driver={SQl Server};'
                   'Server=ALESPANO99PC;' #nome server
                   'Database=work_shop;' #nome database
                   'Trusted_Connection=yes;') #Utilizzare UID=tuo username; PWD=tua password
#Execute SQL Queries
sql_query1=(
'''SELECT  sum(Revenue) as tot_revenue,[State],New_Expansion
from startup_expansion
group by [State],New_Expansion
having New_Expansion='Old'
order by tot_revenue desc
'''
)
df=pd.read_sql(sql_query1,conn)
#Display the DataFrame
df.head(10)
# Out:
# C:\Users\aless\AppData\Local\Temp\ipykernel_428\3272559696.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(sql_query1,conn)
#    tot_revenue        State New_Expansion
# 0      1362468   California           Old
# 1       554964        Texas           Old
# 2       479023      Florida           Old
# 3       298013   Washington           Old
# 4       221025      Alabama           Old
# 5       160046     New York           Old
# 6       158511  Connecticut           Old
# 7       157656      Georgia           Old
# 8       156495     Colorado           Old
# 9       147759     Michigan           Old

# %%
#Qual è il totale delle entrate ('Revenue') ottenuto per ciascuno degli Stati nel DataFrame df, 
#considerando solo le righe in cui 'New Expansion' è uguale a 'New', 
#e quali sono i primi 10 Stati in ordine decrescente di questo totale di entrate?

# %%
#soluzione con pandas
startup_new=startup[startup['new_expansion']=='New'].groupby(['state']).revenue.sum() #ordino in basi agli stati e ai negozi nuovi
startup_new.sort_values(ascending=False).iloc[0:10] #selezioni le prime 10 righe in ordine decrescente
# Out:
# state
# California    141883
# Illinois       91692
# Texas          85605
# Tennessee      55357
# Arizona        48954
# New Jersey     34603
# Name: revenue, dtype: int64

# %%
#soluzioni sql
#soluzione SQl Server
conn=pyodbc.connect('Driver={SQl Server};'
                   'Server=ALESPANO99PC;' #nome server
                   'Database=work_shop;' #nome database
                   'Trusted_Connection=yes;') #Utilizzare UID=tuo username; PWD=tua password
#Execute SQL Queries
sql_query2=(
'''SELECT  sum(Revenue) as Tot_Revenue,[State],New_Expansion
from startup_expansion
group by [State],New_Expansion
having New_Expansion='New'
order by tot_revenue desc
'''
)
df=pd.read_sql(sql_query2,conn)
#Display the DataFrame
df.head(10)
# Out:
# C:\Users\aless\AppData\Local\Temp\ipykernel_428\1798689915.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(sql_query2,conn)
#    Tot_Revenue       State New_Expansion
# 0       141883  California           New
# 1        91692    Illinois           New
# 2        85605       Texas           New
# 3        55357   Tennessee           New
# 4        48954     Arizona           New
# 5        34603  New Jersey           New

# %%
# Aggiungere la colonna ROAS "Return on Advertising Spend" al DataFrame df (Googlare per trovare la formula)
# ROAS = (Revenue / Marketing Spend) * 100
# Visualizzare le prime 10 righe

# %%
#soluzione pandas
startup.insert(7,'ROAS',round((startup.revenue/startup.marketing_spend)*100,0) )

# %%
startup.iloc[0:10]
# Out:
#    store_id           city          state sales_region new_expansion  \
# 0         1         Peoria        Arizona     Region 2           Old
# 1         2        Midland          Texas     Region 2           Old
# 2         3        Spokane     Washington     Region 2           Old
# 3         4         Denton          Texas     Region 2           Old
# 4         5  Overland Park         Kansas     Region 2           Old
# 5         6        Yonkers       New York     Region 1           Old
# 6         7     Birmingham        Alabama     Region 1           Old
# 7         8        Antioch     California     Region 2           Old
# 8         9      Worcester  Massachusetts     Region 1           Old
# 9        10      Rochester       New York     Region 1           Old
#
#    marketing_spend  revenue    ROAS
# 0             2601    48610  1869.0
# 1             2727    45689  1675.0
# 2             2768    49554  1790.0
# 3             2759    38284  1388.0
# ...

# %%
#soluzione SQl Server
conn=pyodbc.connect('Driver={SQl Server};'
                   'Server=ALESPANO99PC;' #nome server
                   'Database=work_shop;' #nome database
                   'Trusted_Connection=yes;') #Utilizzare UID=tuo username; PWD=tua password
#Execute SQL Queries
sql_query3=(
'''UPDATE startup_expansion
SET ROASs = (Revenue/Marketing_Spend)*100);
select *
from startup_expansion
'''
)
df=pd.read_sql(sql_query3,conn)
#Display the DataFrame
df.head(10)
# Out:
# C:\Users\aless\AppData\Local\Temp\ipykernel_7836\1172104139.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(sql_query3,conn)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\OneDrive\Documenti\ANACONDA\lib\site-packages\pandas\io\sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]Sintassi non corretta in prossimità di ')'. (102) (SQLExecDirectW)")
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ...

# %%
# Calcolare il ROAS% Percentuale
# ROAS% = (ROAS% / Marketing Spend) * 100
# Visualizzare le prime 10 righe

# %%
startup.insert(8,'ROAS%',round((startup.ROAS/startup.marketing_spend)*100,0) )

# %%
startup.iloc[0:10]
# Out:
#    store_id           city          state sales_region new_expansion  \
# 0         1         Peoria        Arizona     Region 2           Old
# 1         2        Midland          Texas     Region 2           Old
# 2         3        Spokane     Washington     Region 2           Old
# 3         4         Denton          Texas     Region 2           Old
# 4         5  Overland Park         Kansas     Region 2           Old
# 5         6        Yonkers       New York     Region 1           Old
# 6         7     Birmingham        Alabama     Region 1           Old
# 7         8        Antioch     California     Region 2           Old
# 8         9      Worcester  Massachusetts     Region 1           Old
# 9        10      Rochester       New York     Region 1           Old
#
#    marketing_spend  revenue    ROAS  ROAS%
# 0             2601    48610  1869.0   72.0
# 1             2727    45689  1675.0   61.0
# 2             2768    49554  1790.0   65.0
# ...

# %%
# Aggiungere la colonna Profit al dataframe
# Visualizzare le prime 10 righe

# %%
startup.insert(9,'profit',startup.revenue-startup.marketing_spend )

# %%
startup.iloc[0:10]
# Out:
#    store_id           city          state sales_region new_expansion  \
# 0         1         Peoria        Arizona     Region 2           Old
# 1         2        Midland          Texas     Region 2           Old
# 2         3        Spokane     Washington     Region 2           Old
# 3         4         Denton          Texas     Region 2           Old
# 4         5  Overland Park         Kansas     Region 2           Old
# 5         6        Yonkers       New York     Region 1           Old
# 6         7     Birmingham        Alabama     Region 1           Old
# 7         8        Antioch     California     Region 2           Old
# 8         9      Worcester  Massachusetts     Region 1           Old
# 9        10      Rochester       New York     Region 1           Old
#
#    marketing_spend  revenue    ROAS  ROAS%  profit
# 0             2601    48610  1869.0   72.0   46009
# 1             2727    45689  1675.0   61.0   42962
# 2             2768    49554  1790.0   65.0   46786
# ...
