# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Distanze-geometriche" data-toc-modified-id="Distanze-geometriche-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Distanze geometriche</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Distanza-Euclidea" data-toc-modified-id="Distanza-Euclidea-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Distanza Euclidea</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # BOOTCAMP 1 - TRACCIA

# %% [markdown]
# # Distanze geometriche

# %% [markdown]
# Ricordi il teorema di Pitagora? Se sì, allora potresti ricordare di aver calcolato la distanza tra due punti dati usando il teorema

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', '3w.ipynb', 'Teorema-di-Pitagora-1-960x617.png']

# %%
from IPython import display
display.Image("Teorema-di-Pitagora-1-960x617.png")

# %% [markdown]
# Per calcolare la distanza tra i punti dati A e B il teorema di Pitagora considera la lunghezza degli assi x e y.

# %% [markdown]
# **Una funzione di distanza fornisce la distanza tra gli elementi di un insieme. Se la distanza è zero allora gli elementi sono equivalenti altrimenti sono diversi tra loro.**

# %% [markdown]
# ### Distanza Euclidea

# %% [markdown]
# In matematica, la distanza euclidea è una distanza tra due punti, in particolare è una misura della lunghezza del segmento avente per estremi i due punti.

# %%
import math

# %% [markdown]
# $${P}_1({x}_1,{y}_1)\ {P}_2({x}_2,{y}_2)$$

# %% [markdown]
# $$d({P}_1,{P}_2) := \sqrt{({x}_2 - {x}_1)^2 + ({y}_2 - {y}_1)^2 }$$

# %%
# per lo studente da fare durante in bootcamp : implementa la funzione per il calcolo della distanza euclidea
   # 1. stampa le due coordinate x1 e x2
    # 2. stampa le due coordinate y1 e y2
    # 3. calcola dx e dy (differenza tra le ascisse e le ordinate)
    # 4. calcola la distanza quadrata
    # 5. calcola la radice quadrata e inseriscila in una variabile risultato
    # 6. stampa il risultato
    # 7. ritorna il risultato
    

import math

def DistanzaEuclideaTraDuePunti(x1, y1, x2, y2):
    print("I nostri punti hanno ascissa x1={} e x2={}".format(x1,x2))#stampo i valori delle ascisse x1 e x2
    print("I nostri punti hanno ordinata y1={} e y2={}".format(y1,y2))#stampo i valori delle ordinate y1 e y2
    dx=x2-x1 #differenza ascisse
    dy=y2-y1 #differenza ordinate
    dxy=pow(dx,2)+pow (dy,2) #calcolo la distanza quadrata,se voglio un numero intero posso mettere dxy=int()
    d=math.sqrt (dxy) #calcolo la radice quadrata e la metto in una variabile
    print("La distanza tra di due punti è ",d)#stampo la variabile
    return d #ritorno la variabile
    

    
    
DistanzaEuclideaTraDuePunti(3,-2,4,-5)
# Out:
# I nostri punti hanno ascissa x1=3 e x2=4
# I nostri punti hanno ordinata y1=-2 e y2=-5
# La distanza tra di due punti è  3.1622776601683795
# 3.1622776601683795

# %%
# %whos
# Out:
# Variable                      Type        Data/Info
# ---------------------------------------------------
# DistanzaEuclideaTraDuePunti   function    <function DistanzaEuclide<...>ti at 0x000001C089E31360>
# math                          module      <module 'math' (built-in)>
